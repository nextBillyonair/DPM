# %%
from dpm.monte_carlo.mcmc.simulated_annealing import *
from dpm.distributions import Normal, MixtureModel, GumbelMixtureModel
from dpm.visualize import plot_hist, plot_mcmc, plot_model

# %%
# model = Normal(5, 4)
model = MixtureModel([Normal(-3, 1), Normal(3, 1)], [0.5, 0.5])
plot_model(model)

# %%
samples = simulated_annealing(model, 
            annealing_scheduler=logarithmic_annealing,
            initial_temperature=10., burn_in=0,
            gamma=1.0)

# %%
plot_mcmc(samples)

# %%
plot_hist(samples)
