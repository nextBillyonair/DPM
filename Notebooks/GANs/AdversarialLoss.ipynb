# %%
# %matplotlib inline
from dpm.train import train
from dpm.visualize import plot_model, plot_models, plot_stats, plot_hist, plot_hists
from dpm.distributions import Normal
from dpm.mixture_models import MixtureModel
from pprint import pprint
import matplotlib.pyplot as plt

# %%
from dpm.adversarial_loss import GANLoss, WGANLoss, LSGANLoss, MMGANLoss

# %%
q_model = MixtureModel([Normal([-0.5],[[1.0]]), Normal([0.5],[[1.0]])], [0.5, 0.5])
p_model = MixtureModel([Normal([2.3], [[2.2]]), Normal([-2.3], [[2.2]])], [0.5, 0.5])

plot_models(p_model, q_model); plt.show()

# %%
q_model = MixtureModel([Normal([-0.5],[[1.0]]), Normal([0.5],[[1.0]])], [0.5, 0.5])
p_model = MixtureModel([Normal([2.3], [[2.2]]), Normal([-2.3], [[2.2]])], [0.5, 0.5])


stats = train(p_model, q_model, GANLoss(p_model.n_dims), optimizer="RMSprop", 
              epochs=20000, lr=1e-3, batch_size=512)

plot_stats(stats); plt.show()
plot_models(p_model, q_model); plt.show()

# %%
q_model = MixtureModel([Normal([-0.5],[[1.0]]), Normal([0.5],[[1.0]])], [0.5, 0.5])
p_model = MixtureModel([Normal([2.3], [[2.2]]), Normal([-2.3], [[2.2]])], [0.5, 0.5])


stats = train(p_model, q_model, WGANLoss(p_model.n_dims), optimizer="RMSprop", 
              epochs=20000, lr=1e-3, batch_size=512)

plot_stats(stats); plt.show()
plot_models(p_model, q_model); plt.show()

# %%
q_model = MixtureModel([Normal([-0.5],[[1.0]]), Normal([0.5],[[1.0]])], [0.5, 0.5])
p_model = MixtureModel([Normal([2.3], [[2.2]]), Normal([-2.3], [[2.2]])], [0.5, 0.5])


stats = train(p_model, q_model, WGANLoss(p_model.n_dims, grad_penalty=10.), optimizer="RMSprop", 
              epochs=20000, lr=1e-3, batch_size=512)

plot_stats(stats); plt.show()
plot_models(p_model, q_model); plt.show()

# %%
q_model = MixtureModel([Normal([-0.5],[[1.0]]), Normal([0.5],[[1.0]])], [0.5, 0.5])
p_model = MixtureModel([Normal([2.3], [[2.2]]), Normal([-2.3], [[2.2]])], [0.5, 0.5])


stats = train(p_model, q_model, WGANLoss(p_model.n_dims, use_spectral_norm=True), optimizer="RMSprop", 
              epochs=20000, lr=1e-3, batch_size=512)

plot_stats(stats); plt.show()
plot_models(p_model, q_model); plt.show()

# %%
q_model = MixtureModel([Normal([-0.5],[[1.0]]), Normal([0.5],[[1.0]])], [0.5, 0.5])
p_model = MixtureModel([Normal([2.3], [[2.2]]), Normal([-2.3], [[2.2]])], [0.5, 0.5])


stats = train(p_model, q_model, LSGANLoss(p_model.n_dims), optimizer="RMSprop", 
              epochs=20000, lr=1e-3, batch_size=512)

plot_stats(stats); plt.show()
plot_models(p_model, q_model); plt.show()

# %%
q_model = MixtureModel([Normal([-0.5],[[1.0]]), Normal([0.5],[[1.0]])], [0.5, 0.5])
p_model = MixtureModel([Normal([2.3], [[2.2]]), Normal([-2.3], [[2.2]])], [0.5, 0.5])


stats = train(p_model, q_model, MMGANLoss(p_model.n_dims), optimizer="RMSprop", 
              epochs=20000, lr=1e-3, batch_size=512)

plot_stats(stats); plt.show()
plot_models(p_model, q_model); plt.show()
