# %%
from distributions import Uniform
from loss import ForwardKL, ReverseKL
from mcmc import metropolis_hastings
from train import train
from visualize import plot_models, plot_stats, plot_model, plot_hist, plot_mcmc

# %%
p_model = Uniform([-1.0], [5.0])
q_model = Uniform([0.0], [1.0])

plot_models(p_model, q_model)
stats = train(p_model, q_model, ForwardKL, epochs=5000,
              track_parameters=True)
plot_stats(stats)
plot_models(p_model, q_model)

# %%
samples = metropolis_hastings(p_model, epochs=25000, keep=111000)

# %%
plot_hist(samples)
plot_mcmc(samples)
